# %% [markdown]
# # Image Classification - Lab
#
# ## Introduction
#
# Note: this is a truncated lab, due to time constrains I was not able to get the data properly downloaded and my manual attempt failed to bring all the relevant information. I am leaving it as is here, and may be coming back on a later date to complete the exercise.
#
# Now that you have a working knowledge of CNNs and have practiced implementing associated techniques in Keras, its time to put all of those skills together. In this lab, you'll work to complete a [Kaggle competition](https://www.kaggle.com/c/dog-breed-identification) on classifying dog breeds.
#
#
# ## Objectives
#
# In this lab you will:
#
# - Compare and apply multiple techniques for tuning a model using data augmentation and pretrained models
#
# ## Download and Load the Data
#
# Start by downloading the data locally and loading it into a Pandas DataFrame. Be forewarned that this dataset is fairly large and it is advisable to close other memory intensive applications. Note: Part of the purpose of this lab is to use Jupyter Notebook locally.
#
# The data can be found [here](https://www.kaggle.com/c/dog-breed-identification/data).
#
# It's easiest if you download the data into this directory on your local computer. From there, be sure to uncompress the folder and subfolders. If you download the data elsewhere, be sure to modify the file path when importing the file below.

# %%
# No code per se, but download and decompress the data
# Brought in manually into a "Data" folder

# %% [markdown]
# ## Preprocessing
#
# Now that you've downloaded the data, its time to prepare it for some model building! You'll notice that the current structure provided is not the same as our lovely preprocessed folders that you've been given to date. Instead, you have one large training folder with images and a csv file with labels associated with each of these file types.
#
# Use this to create a directory substructure for a train-validation-test split as we have done previously. Also recall that you'll also want to use one-hot encoding as you are now presented with a multi-class problem as opposed to simple binary classification.

# %%
# import
import pandas as pd
import numpy as np
import os
import shutil
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# open the labels.csv
df = pd.read_csv('dog_breeds/labels.csv')
df.head()
# Out:
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
# List the first 5 files in the directory
files = os.listdir('dog_breeds/')[:5]
print(files)
# Out:
# ['labels.csv', 'sample_submission.csv']

# %% [markdown]
# In order to input the data into our standard pipeline, you'll need to organize the image files into a nested folder structure. At the top level will be a folder for the training data, a folder for the validation data, and a folder for the test data. Within these top directory folders, you'll then need to create a folder for each of the categorical classes (in this case, dog breeds). Finally, within these category folders you'll then place each of the associated image files. To save time, do this for just 3 of the dog breeds such as `'boston_bull'`, `'toy_poodle'`, and `'scottish_deerhound'`.
#
# You're nested file structure should look like this:
# * train
#     * category_1
#     * category_2
#     * category_3
#     ...
# * val
#     * category_1
#     * category_2
#     * category_3
#     ...
# * test
#     * category_1
#     * category_2
#     * category_3
#     ...
#
# > **Hint**: To do this, you can use the `os` module which will you can use to execute many common bash commands straight from your python interpreter. For example, here's how you could make a new folder:
#
# ```python
# import os
# os.mkdir('New_Folder_Name')
# ```
# Start by creating top level folders for the train, validation, and test sets. Then, use your pandas DataFrame to split the example images for each breed of dog into a 80% train set, and 10% validation and test sets. Use `os.path.join()` with the information from the DataFrame to construct the relevant file path. With this, place the relevant images using the `shutil.copy()` into the appropriate directory.
#
# >> **Note**: It is worthwhile to try this exercise on your own, but you can also use the images stored under the `'data_org_subset/'` folder of this repository, in which the Kaggle dataset has already been subset and preprocessed.

# %%
# Your code here; transform the image files and then load them into Keras as tensors 
# (be sure to perform a train-val-test split)
# Select only the 3 specified dog breeds
selected_breeds = ['boston_bull', 'toy_poodle', 'scottish_deerhound']
selected_data = df[df['breed'].isin(selected_breeds)]

# Split the data into train, validation, and test sets (80%, 10%, 10%)
train_data, test_val_data = train_test_split(selected_data, test_size=0.2, random_state=42)
val_data, test_data = train_test_split(test_val_data, test_size=0.5, random_state=42)

# Define the top-level directories
base_dir = 'dog_data'
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

# Create 'train', 'val', 'test' directories if they don't exist
for directory in [train_dir, val_dir, test_dir]:
    os.makedirs(directory, exist_ok=True)

# Function to copy images into respective folders if the file exists
def copy_images(data, src_directory, dst_directory):
    for index, row in data.iterrows():
        img_filename = row['id'] + '.jpg'
        src = os.path.join(src_directory, img_filename)
        dst = os.path.join(dst_directory, img_filename)
        if os.path.isfile(src):  # Check if the file exists before copying
            shutil.copy(src, dst)

# Copy images to train, validation, and test directories
copy_images(train_data, 'dog_breeds/train/', train_dir)
copy_images(val_data, 'dog_breeds/train/', val_dir)
copy_images(test_data, 'dog_breeds/train/', test_dir)

# %%
# Directories for train, validation, and test sets
train_dir = 'dog_data/train'
val_dir = 'dog_data/val'
test_dir = 'dog_data/test'

# Image data generators with augmentation for train set
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# Image data generators for validation and test sets (only rescaling)
val_test_datagen = ImageDataGenerator(rescale=1./255)

# Flow training images in batches using train_datagen generator
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical'
)

# Flow validation images in batches using val_test_datagen generator
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical'
)

# Flow test images in batches using val_test_datagen generator
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 0 images belonging to 1 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.

# %%
print('Number of unique breeds:', df.breed.nunique())
print(df.breed.value_counts()[:10])
# Out:
# Number of unique breeds: 120
# breed
# scottish_deerhound      126
# maltese_dog             117
# afghan_hound            116
# entlebucher             115
# bernese_mountain_dog    114
# shih-tzu                112
# great_pyrenees          111
# pomeranian              111
# basenji                 110
# samoyed                 109
# Name: count, dtype: int64

# %%
old_dir = 'dog_breeds/train/'
new_root_dir = 'data_org_subset/'

# Create new_root_dir if it doesn't exist
os.makedirs(new_root_dir, exist_ok=True)

dir_names = ['train', 'val', 'test']
for d in dir_names:
    new_dir = os.path.join(new_root_dir, d)
    os.makedirs(new_dir, exist_ok=True)
    
for breed in ['boston_bull', 'toy_poodle', 'scottish_deerhound']:
    print('Moving {} pictures.'.format(breed))
    # Create sub_directories
    for d in dir_names:
        new_dir = os.path.join(new_root_dir, d, breed)
        os.makedirs(new_dir, exist_ok=True)
    
    # Subset dataframe into train, validate, and test sets
    # Split is performed here to maintain class distributions
    temp = df[df.breed == breed]
    train, validate, test = np.split(temp.sample(frac=1), [int(.8*len(temp)), int(.9*len(temp))])
    print('Split {} imgs into {} train, {} val, and {} test examples.'.format(len(temp),
                                                                              len(train),
                                                                              len(validate),
                                                                              len(test)))
    for i, temp_split in enumerate([train, validate, test]):
        for row in temp_split.index:
            filename = temp_split['id'][row] + '.jpg'
            origin = os.path.join(old_dir, filename)
            destination = os.path.join(new_root_dir, dir_names[i], breed, filename)
            
            # Check if the file exists before copying
            if os.path.isfile(origin):
                shutil.copy(origin, destination)
            else:
                print(f"File {origin} not found.")
# Out:
# Moving boston_bull pictures.
# Split 87 imgs into 69 train, 9 val, and 9 test examples.
# File dog_breeds/train/309bf67309851334acebe0003c21b180.jpg not found.
# File dog_breeds/train/faa2c24c801b37aca93ac744da51c2c3.jpg not found.
# File dog_breeds/train/8200d65aa11022a2d877afa6cb632a7e.jpg not found.
# File dog_breeds/train/c825a17e20a29f767bf4b915d036c502.jpg not found.
# File dog_breeds/train/146be641443a270dd8116f65d53d0c9d.jpg not found.
# File dog_breeds/train/20be3ce1dd7db9194c856726c2f154a3.jpg not found.
# File dog_breeds/train/69406cd21bac290f6c6eaa6b0a968fc1.jpg not found.
# File dog_breeds/train/d0abd5df53b9a41a506ea217a70a961a.jpg not found.
# File dog_breeds/train/a55afed96114f7dcc48ee9ed9731f7da.jpg not found.
# File dog_breeds/train/8233f609f7a39f0f834894e761d73aa0.jpg not found.
# File dog_breeds/train/99fbeea51938834952e2bd18d3244dff.jpg not found.
# File dog_breeds/train/6f0da929ad7f82be1c274dc0d2f56a4c.jpg not found.
# File dog_breeds/train/d6857f130c251f01ab973358cbfccce1.jpg not found.
# File dog_breeds/train/c1e854371a2316fc28ccb4cb5527c478.jpg not found.
# File dog_breeds/train/fae9b4b30924265a3098d8e524fc47d2.jpg not found.
# File dog_breeds/train/07d7cfbdbd3682cae50902b53c798028.jpg not found.
# File dog_breeds/train/33a255a956f02a591865dbe9768eff77.jpg not found.
# File dog_breeds/train/f19b045bcf373d6fcf05c80247850d50.jpg not found.
# File dog_breeds/train/fd73ff7c6b24e7292701305e8c7c32c2.jpg not found.
# File dog_breeds/train/c66bea53a3b615683a2248d664fd3813.jpg not found.
# File dog_breeds/train/46ebb81214e6fb568f5be0495ac7a63e.jpg not found.
# File dog_breeds/train/b200db1a2dc5f3d5a6521aac2130713c.jpg not found.
# File dog_breeds/train/9bdbaa146c1c71e9db759348e9f5f56a.jpg not found.
# File dog_breeds/train/e86f7777b271c54f7d0d6a228637c8d3.jpg not found.
# File dog_breeds/train/5662700344c5f0cc5ac699a6d67fe1db.jpg not found.
# File dog_breeds/train/56a55febaf11773cfa1802f01104d7c0.jpg not found.
# File dog_breeds/train/d84cd331a97cb5ee7d08974724f7055f.jpg not found.
# File dog_breeds/train/ae8693b4868b1744be1fefb328a8a486.jpg not found.
# File dog_breeds/train/251c34f3b527215f0b865a4580bf4e95.jpg not found.
# File dog_breeds/train/346c9842d580b40bd7ca52d4095e3ea4.jpg not found.
# File dog_breeds/train/c9f0a7765a138e2850c6ed6538c2134f.jpg not found.
# File dog_breeds/train/b076ead1c800594f7aad2ff784bc3427.jpg not found.
# File dog_breeds/train/30ff784cea2bfc2a6df330f58e781b98.jpg not found.
# File dog_breeds/train/10730dfd280bb4b2723dc677378f2ff1.jpg not found.
# File dog_breeds/train/118060ca946af5cfd1b3bbe030f9003c.jpg not found.
# File dog_breeds/train/d5470b760dc855b84add98748e03bd77.jpg not found.
# File dog_breeds/train/d62be3aa1b627562ab1b85ce73f9fede.jpg not found.
# File dog_breeds/train/2cddd21e49ea9246eaa8012ae03aedac.jpg not found.
# File dog_breeds/train/df12a66b9b154c8bbe922846944e2ef2.jpg not found.
# File dog_breeds/train/9a0bd02ffe451fc028e8e9a4ecef22d4.jpg not found.
# File dog_breeds/train/30c2c1c75e271b8baae54908bfd8e98a.jpg not found.
# File dog_breeds/train/387ae89153da8b0171322ab0cd54923e.jpg not found.
# File dog_breeds/train/fa0b4de9dbacd9faa3a5a4f2adc63195.jpg not found.
# File dog_breeds/train/ae588184cfac8fb06f9ba96b44b63e4d.jpg not found.
# File dog_breeds/train/c96b81edd143405fc0ab3a6d7b2fda00.jpg not found.
# File dog_breeds/train/c59df3c5d6b7f12d5086f1b7cf64858b.jpg not found.
# File dog_breeds/train/bf904a3e0ad73be75221a5fc271bece6.jpg not found.
# File dog_breeds/train/632e8ef55138a10cdcf56a7bd1e125f4.jpg not found.
# File dog_breeds/train/2de8d47770da0fb805ccf8461d062c54.jpg not found.
# File dog_breeds/train/55168e5cb057b6425ec04e70ccd76da1.jpg not found.
# File dog_breeds/train/44e59225be92c4cecb96acc669962242.jpg not found.
# File dog_breeds/train/aa7d9f08fc9ac1d45117848137adce9c.jpg not found.
# File dog_breeds/train/67fd6f452620bb07abf1d0c171d4c672.jpg not found.
# File dog_breeds/train/9a2bee2420ddad2275d50ece888ee34b.jpg not found.
# File dog_breeds/train/b1f80a20da3b0bc83d6e5d526592ef92.jpg not found.
# File dog_breeds/train/3c4a342c6aca01e2a31c03b072916fbe.jpg not found.
# File dog_breeds/train/dd19ba0779065dbab0c28842fdf5851f.jpg not found.
# File dog_breeds/train/c790a45b98d586f77f428b07f1fb1f17.jpg not found.
# File dog_breeds/train/ee88ac6bfed3abb8713bbc988b87eb80.jpg not found.
# File dog_breeds/train/13f939b9b15ec56409a21017263db93c.jpg not found.
# File dog_breeds/train/878499737e214678c2947b8b4c82a6f7.jpg not found.
# File dog_breeds/train/9f3e89f1166b8a5b9161d934c8ea79c4.jpg not found.
# File dog_breeds/train/36549cf287a833afff09821e55a923d8.jpg not found.
# File dog_breeds/train/0b3d3120a62c2bc280f589d473041d06.jpg not found.
# File dog_breeds/train/baa740b07dfb86b187041dd39a2eef1b.jpg not found.
# File dog_breeds/train/172fcb0b8bbd67401c9e53e5f9bf39bc.jpg not found.
# File dog_breeds/train/8befc822b56b744d72872428a0ef4851.jpg not found.
# File dog_breeds/train/a23f53a45ee2d6d6218c7e3b70234091.jpg not found.
# File dog_breeds/train/79bef9a1aebcd3246ec1de034107dd87.jpg not found.
# File dog_breeds/train/c0d10ee669b1ccc5bc60950efd19cd53.jpg not found.
# File dog_breeds/train/2c5f6c1c3acef3e307fd92378caf198c.jpg not found.
# File dog_breeds/train/0755a940eac9a9b8cf0328b4be062096.jpg not found.
# File dog_breeds/train/010d65bd29d246aea53d9849da142ccf.jpg not found.
# File dog_breeds/train/99c80aaf5bc0531ed9b177b0c2b696a9.jpg not found.
# File dog_breeds/train/59299f7e10c91e2712d9d7acd9e80ce9.jpg not found.
# File dog_breeds/train/240ce7dee9610547cad87c92fcff7dbb.jpg not found.
# File dog_breeds/train/cd9045d7c082dc4427bfd026d03c0e69.jpg not found.
# File dog_breeds/train/16aaa590e39530bc1cb319fc7d89c00e.jpg not found.
# File dog_breeds/train/65c0f97251e14cfddda723b209114f80.jpg not found.
# File dog_breeds/train/2fde20eb9c645c02a583ef01ebce6374.jpg not found.
# File dog_breeds/train/000bec180eb18c7604dcecc8fe0dba07.jpg not found.
# File dog_breeds/train/d6fb643ed203d7d01db9a4744526f2ea.jpg not found.
# File dog_breeds/train/6f0d4c29c6bd29af6277fdd2afd26187.jpg not found.
# File dog_breeds/train/b1e148a8ac377ba2148d061db9fa35da.jpg not found.
# File dog_breeds/train/98e98242b7e57c718a0d1a643d40146d.jpg not found.
# File dog_breeds/train/776a702e80fc75c7969198ede3ee0aad.jpg not found.
# File dog_breeds/train/6702f6c6b4b6a64f4b16364061cb546d.jpg not found.
# Moving toy_poodle pictures.
# Split 80 imgs into 64 train, 8 val, and 8 test examples.
# File dog_breeds/train/43d5a0815fe2887f676090b9434fac0c.jpg not found.
# File dog_breeds/train/5e10c59dd98139adcdb59986ab9e5b19.jpg not found.
# File dog_breeds/train/51cf930fcaa72551347eaed4b2e08f1b.jpg not found.
# File dog_breeds/train/7539976d416b8f178310df9d03538c10.jpg not found.
# File dog_breeds/train/d8275152fe9027835bec0c405d131a2b.jpg not found.
# File dog_breeds/train/d88d9d949d676cd61c9bd5fd7e50acf0.jpg not found.
# File dog_breeds/train/bc218eeb424cf93092b0a0b23035bbad.jpg not found.
# File dog_breeds/train/5cd7d9abb1a7d02a4f517b81c422d4f4.jpg not found.
# File dog_breeds/train/03da788cc7e5c111575daf04e7e3910c.jpg not found.
# File dog_breeds/train/69e4b2d1647eb59844434146b29096a3.jpg not found.
# File dog_breeds/train/1d25a5b2fb305047bfef877b77af6a36.jpg not found.
# File dog_breeds/train/706502a6f7f079d0dd4fe5287a8c3d59.jpg not found.
# File dog_breeds/train/b9cc361e5493db5effda92f09ab61f92.jpg not found.
# File dog_breeds/train/29b06acb65e3873dfab2a7b2581d6a35.jpg not found.
# File dog_breeds/train/23259c54997519723801e82e86dcc804.jpg not found.
# File dog_breeds/train/9e577dd7c29bc6074a80fed5ade75d0d.jpg not found.
# File dog_breeds/train/addf2f5e7426173ffb795fa485edae63.jpg not found.
# File dog_breeds/train/307849bb1f79442bc19e0002ebd3763d.jpg not found.
# File dog_breeds/train/c0de582157dbd2320e406cdfea59ef11.jpg not found.
# File dog_breeds/train/e673bb6ca717b8dffe3b5ba35da07a83.jpg not found.
# File dog_breeds/train/7db94bf9f2634ed4cb5b8f8212cbd0a7.jpg not found.
# File dog_breeds/train/6b823afef10535744271064bc6666530.jpg not found.
# File dog_breeds/train/2e3a303f1eadaadb80245424f314bbdd.jpg not found.
# File dog_breeds/train/b05d8eb1d33475e05dd986dd0dd2554b.jpg not found.
# File dog_breeds/train/80bdf89655138d620169a90b6dcf3993.jpg not found.
# File dog_breeds/train/06e548623971fbdf8c80b0614f811f50.jpg not found.
# File dog_breeds/train/29f4fbc88dbe90a21ceffa17cd167be0.jpg not found.
# File dog_breeds/train/b04dde81f2e6c0b0a37ecf99714d716e.jpg not found.
# File dog_breeds/train/e4ca855e09eabf518ed39a0a545da981.jpg not found.
# File dog_breeds/train/6d3fc8ed4a7e7cf155795c7f90ef8aec.jpg not found.
# File dog_breeds/train/2e6352e225e1699aefb5a460145f5200.jpg not found.
# File dog_breeds/train/e4a159a9611f2025cecf53bf8e09699b.jpg not found.
# File dog_breeds/train/46c078621fd05d3166b393e0a5104fce.jpg not found.
# File dog_breeds/train/4f3d05b2b3c207dbb50cef30f8870129.jpg not found.
# File dog_breeds/train/dcda81d6b22e37e4c0fc36a383a61e73.jpg not found.
# File dog_breeds/train/7b1d7a6aa4c68b5ef68a5d16d19f2809.jpg not found.
# File dog_breeds/train/a27283e8fe735bf0127fed8bf0807b84.jpg not found.
# File dog_breeds/train/92d23591a857f9adb0024d587683a1cd.jpg not found.
# File dog_breeds/train/6bab1784b0b33075e6d6f26714c1164f.jpg not found.
# File dog_breeds/train/ee8315e3cef238ea380d197ceb26a476.jpg not found.
# File dog_breeds/train/8dd4e667d9ba987fe4c42fbb09206e60.jpg not found.
# File dog_breeds/train/2cbf7946e93d81d8f07b46bd339a1a93.jpg not found.
# File dog_breeds/train/193a03557eb1c0fed9b2ef8f9f9d892f.jpg not found.
# File dog_breeds/train/7645e3e336ea56a3d2acdd258190893a.jpg not found.
# File dog_breeds/train/012ff2d21dad14452ea16b4cda7eef4c.jpg not found.
# File dog_breeds/train/ab5c5ee4b0431f391fde0ba59a253907.jpg not found.
# File dog_breeds/train/433b72e0db28d47b76a7fa8a1361be0b.jpg not found.
# File dog_breeds/train/0b30d48dd2818cdea768d884623e8c2a.jpg not found.
# File dog_breeds/train/ebfc57d72a4167ec2f738f2adec52e31.jpg not found.
# File dog_breeds/train/17e3b8acf23f7943b04dc680fc1bda0d.jpg not found.
# File dog_breeds/train/d7b8e8b5851e49502dffc5f9654743be.jpg not found.
# File dog_breeds/train/3c1461a647fe9318acb8d3969f6f6c64.jpg not found.
# File dog_breeds/train/abe55e39cafb1abc85bb6b00376222f0.jpg not found.
# File dog_breeds/train/727af41f3b77a02a45ccdf1d040d658b.jpg not found.
# File dog_breeds/train/aa4b8e10696a7e2f8d07a7b13c1f5c6b.jpg not found.
# File dog_breeds/train/f58364e9a181f9d7e149f4cec3e9ec80.jpg not found.
# File dog_breeds/train/aa52399aa598792ef63fe14828660bc3.jpg not found.
# File dog_breeds/train/cd9a0ccbb1b02224208062f3778444ef.jpg not found.
# File dog_breeds/train/23e73ebc4dd90b6d9269bdf0c499cce1.jpg not found.
# File dog_breeds/train/a7f36feff3c6fc2406d316f75381c491.jpg not found.
# File dog_breeds/train/06cceae049531cdb98fe67d912aa58a8.jpg not found.
# File dog_breeds/train/f89759123d85d4135ed4bdce6923ad6a.jpg not found.
# File dog_breeds/train/1d8ace26f651b160925d5b859351c826.jpg not found.
# File dog_breeds/train/2ebd03cafba22edf2556cda2a6759e19.jpg not found.
# File dog_breeds/train/0ea00d73664139c52ee1eaabc77ea478.jpg not found.
# File dog_breeds/train/84dfe42ce71204b367c2b4000eb6ba5c.jpg not found.
# File dog_breeds/train/d194f1de2eb1f5037481388b04452b6b.jpg not found.
# File dog_breeds/train/8d636c0e0e64295df6bbd2e434b47459.jpg not found.
# File dog_breeds/train/d2a7bd18d1cf5d798648f2a51fab39da.jpg not found.
# File dog_breeds/train/f64d8dfc5544c9fb4bdc578a7756dfd7.jpg not found.
# File dog_breeds/train/24e5ea89ab96f5534ca2be217ef17643.jpg not found.
# File dog_breeds/train/4dfaa8dee5203f7d0d4c29a684627abc.jpg not found.
# File dog_breeds/train/1268223049f00d74f20d4f2af3126234.jpg not found.
# File dog_breeds/train/8dc51b503e88122ad71dd0c7569fd3bb.jpg not found.
# File dog_breeds/train/16d2d5edf52892450e38aa4f766c2eea.jpg not found.
# File dog_breeds/train/073b9a44c4761fa0792943b61b9c812c.jpg not found.
# File dog_breeds/train/099db37801090ed56bbc95c13d3799b9.jpg not found.
# File dog_breeds/train/c5b95a6c73427b6901110e1f11bc5569.jpg not found.
# File dog_breeds/train/fe0ca31ba19fc97e9644ac4daafa7e36.jpg not found.
# File dog_breeds/train/d5a9fac2fa046e3649c845aa9d286e98.jpg not found.
# Moving scottish_deerhound pictures.
# Split 126 imgs into 100 train, 13 val, and 13 test examples.
# File dog_breeds/train/bac48c1d1224be5945c7a0b823f919b6.jpg not found.
# File dog_breeds/train/72368f3e9b7974dc29e284b7d80edb42.jpg not found.
# File dog_breeds/train/a25ddbe69eddafe9bbf2e542dc8cb487.jpg not found.
# File dog_breeds/train/f921b60576b1055884307f1f6d42997f.jpg not found.
# File dog_breeds/train/12eb341a614941c33777c708d43a042f.jpg not found.
# File dog_breeds/train/e1f5774f729e887a7314dfaa8fcb0b8a.jpg not found.
# File dog_breeds/train/f901c393eca491f1c03b88b31fa956fc.jpg not found.
# File dog_breeds/train/2f134ad25b7f825ab28eb2a5dba0c638.jpg not found.
# File dog_breeds/train/058d4bfce39c9f1157ca4c1b019bbf1a.jpg not found.
# File dog_breeds/train/f1a9a63f0ec70494ec2050de0fd39402.jpg not found.
# File dog_breeds/train/cdffff7690054e91eab8e7237df12406.jpg not found.
# File dog_breeds/train/8d4b28ae56c225f870139cdfeff5131c.jpg not found.
# File dog_breeds/train/af5ea2c0ba78ce06af14acc92b0c8803.jpg not found.
# File dog_breeds/train/a5e12305354299b560665bffbd811f8d.jpg not found.
# File dog_breeds/train/48691e705d9c663941873256da0cc683.jpg not found.
# File dog_breeds/train/77206fa9b8356386a19d7d5e130f863a.jpg not found.
# File dog_breeds/train/fe50bac6c389d137ea01c9cfc7346ca8.jpg not found.
# File dog_breeds/train/b7bcf988b4dff199ec966696225a3aa0.jpg not found.
# File dog_breeds/train/37f535c853a2d1c0dd13b94e9545db81.jpg not found.
# File dog_breeds/train/a2974cd29095193d21bad9d4429a0146.jpg not found.
# File dog_breeds/train/6b5d909216e2d5d6e25487777ed32c29.jpg not found.
# File dog_breeds/train/7fcefdba3fd6402705bdf39258177d42.jpg not found.
# File dog_breeds/train/2c99c9ae27d34737a092ebfaeb791648.jpg not found.
# File dog_breeds/train/056b535b441278e83839984f1b1da0a6.jpg not found.
# File dog_breeds/train/83b1020ad3fce7d18c4699dd292a3c93.jpg not found.
# File dog_breeds/train/241bb47ab02ab1b01aad84ffb6524b6d.jpg not found.
# File dog_breeds/train/4edfc93408cef61336881d3016df6e6d.jpg not found.
# File dog_breeds/train/d34ca643d6c19c9943b40af456e62cd3.jpg not found.
# File dog_breeds/train/edb50bbbbf53fb184cbc04f21dd97b81.jpg not found.
# File dog_breeds/train/3f0c77e6089a64f7083277b6bf22759e.jpg not found.
# File dog_breeds/train/652230a69f3da993b74d0ce49b905550.jpg not found.
# File dog_breeds/train/d482fb5576279496d6f8d72bf6b93d9f.jpg not found.
# File dog_breeds/train/41f7290c2777a4f18d6082c7683096a9.jpg not found.
# File dog_breeds/train/59d8b381d23f02be989374df44cfd36d.jpg not found.
# File dog_breeds/train/8a4830e8d2f106d5a0c46ef82be96b0c.jpg not found.
# File dog_breeds/train/19205fceb3eb41ba27f1b0b946934789.jpg not found.
# File dog_breeds/train/44748d61290af0658e499cc4b046b6c9.jpg not found.
# File dog_breeds/train/7bdb38da91169debedf3f5b2bffdc014.jpg not found.
# File dog_breeds/train/8b27fd53a34c667b41ec5cf13be22de6.jpg not found.
# File dog_breeds/train/3fd4d0daf3781126dde8e6d4e47ce4dd.jpg not found.
# File dog_breeds/train/8233bf4095e1baf15fe06d98c9083906.jpg not found.
# File dog_breeds/train/c13427fc3db9194dac02b1721bd10fe4.jpg not found.
# File dog_breeds/train/669d0c285f652eb96a97f45b8c7f1bb4.jpg not found.
# File dog_breeds/train/9bef849130e5759f4e77d9cdbd72034a.jpg not found.
# File dog_breeds/train/83c2d7419b0429b9fe953bc1b6cddbec.jpg not found.
# File dog_breeds/train/d99e075b2610dd70e27a95c5f16e3b8d.jpg not found.
# File dog_breeds/train/01e787576c003930f96c966f9c3e1d44.jpg not found.
# File dog_breeds/train/c9bbc4ce586c0d73e14bee1b1e674ba9.jpg not found.
# File dog_breeds/train/77c4f20be5520f5394ad2a1e7181ba51.jpg not found.
# File dog_breeds/train/435b3053411e22ac8b6164cd5513d282.jpg not found.
# File dog_breeds/train/3b3dc6881003ac59ecc5321adbaa9350.jpg not found.
# File dog_breeds/train/9ad7b84e62adb614a516e742d2df0f1b.jpg not found.
# File dog_breeds/train/1a5dd02401d05d66bbc9eb1e13a096fc.jpg not found.
# File dog_breeds/train/3f86f07cc17912038aa62c83f044163e.jpg not found.
# File dog_breeds/train/9468380b65de0c9bcdaa5921305fe362.jpg not found.
# File dog_breeds/train/eb53813edf96c446e5acaa06c0deca9e.jpg not found.
# File dog_breeds/train/becdcf664798e240a8eb4fea44de4f94.jpg not found.
# File dog_breeds/train/a32893132f6fbb3635df77c157c7d8e0.jpg not found.
# File dog_breeds/train/f194e48d99e5e0f279eb8cd5e6872e36.jpg not found.
# File dog_breeds/train/6b8ac349a4550590b06c83996ed714e8.jpg not found.
# File dog_breeds/train/c3008b4470c7c53a12d4490e51643548.jpg not found.
# File dog_breeds/train/a72448bdbaa5e486245d38f50ca37e42.jpg not found.
# File dog_breeds/train/0fee7eb61d52b589414845803d73f2f9.jpg not found.
# File dog_breeds/train/9bf3d79a743c864430ddc69fcc4e4c0d.jpg not found.
# File dog_breeds/train/52ccec304f83c67eb2c996f274e7d640.jpg not found.
# File dog_breeds/train/226ffd2a0ab7fe198b97bf255711ee82.jpg not found.
# File dog_breeds/train/166da5b561393f0dda932f562c39bc6b.jpg not found.
# File dog_breeds/train/7aafb1cd5aba33e4097e41ea4166ece2.jpg not found.
# File dog_breeds/train/838f27799a1ed487d9f48d7a49a047b3.jpg not found.
# File dog_breeds/train/859deae5a4eb97d0d32c94eb936228ed.jpg not found.
# File dog_breeds/train/890efbec7147c2887c460be0af763381.jpg not found.
# File dog_breeds/train/a8965b5b9649335721b516e0e6e67122.jpg not found.
# File dog_breeds/train/5fd220be94ab7c0058bc3aef9134d160.jpg not found.
# File dog_breeds/train/eda44fc4fded6ff594aeb833634ea44c.jpg not found.
# File dog_breeds/train/c0e6e8660b28cd6f91bee7e75f63cde1.jpg not found.
# File dog_breeds/train/cdee721aacdca2d44cd02200f2e1e62c.jpg not found.
# File dog_breeds/train/136e0fc1f67b72037c0e60faff6061f2.jpg not found.
# File dog_breeds/train/430d1dd6454063f3dadadd8cd08821be.jpg not found.
# File dog_breeds/train/291f8ff3c8a5ad5451f42d6b5119963e.jpg not found.
# File dog_breeds/train/f5c21557b2fdf621b48720357ea35df2.jpg not found.
# File dog_breeds/train/92cd9b84d46f409747f172060b45200d.jpg not found.
# File dog_breeds/train/ad15d290cc87d4c3afbe21061c71e465.jpg not found.
# File dog_breeds/train/0bad79c06832a1bdeaedbbb50a28450a.jpg not found.
# File dog_breeds/train/7eef63f380bd2c73b73e0f17d3420dff.jpg not found.
# File dog_breeds/train/0eaea4c6fe055607ed8322db0306285f.jpg not found.
# File dog_breeds/train/486ae1ca61f84a930a58ece5d8c8d95e.jpg not found.
# File dog_breeds/train/7ecd9ea72881883e8a0c708425cb9b2b.jpg not found.
# File dog_breeds/train/9777f569b6116476eeade6c12a234d8e.jpg not found.
# File dog_breeds/train/73ec0cb4913739425e88255f57e49589.jpg not found.
# File dog_breeds/train/da82351431ac8992359ffca87bca053d.jpg not found.
# File dog_breeds/train/0042188c895a2f14ef64a918ed9c7b64.jpg not found.
# File dog_breeds/train/8470a6fdf4db9b088494aaa9384ba9d0.jpg not found.
# File dog_breeds/train/88928ad88da921d74a26acb27fb3028a.jpg not found.
# File dog_breeds/train/87028ba151a48e01ea87c063e420798b.jpg not found.
# File dog_breeds/train/89cbfc8c3745a9c14c2b73765f30fc9a.jpg not found.
# File dog_breeds/train/bd8cb94a46ae36e1bf2f0952a3e4a79e.jpg not found.
# File dog_breeds/train/c81748117aecc58678b1677528fdab97.jpg not found.
# File dog_breeds/train/5de5c4c802931e60e1428fc0243267eb.jpg not found.
# File dog_breeds/train/05719b998e57a11b863a322ecc7652a5.jpg not found.
# File dog_breeds/train/03dc61595ad9dbf49e3998cf586ca8cb.jpg not found.
# File dog_breeds/train/e5f8c5b22071d0a266d80e3f9edc1cd0.jpg not found.
# File dog_breeds/train/68b359736db9580b8f7a8f0a17d758b6.jpg not found.
# File dog_breeds/train/89c587a6a853c816d3cea9337a8e814a.jpg not found.
# File dog_breeds/train/27290de13a539134e06d9a5af13e23a1.jpg not found.
# File dog_breeds/train/bf7004de0f825049194139051f7a8025.jpg not found.
# File dog_breeds/train/d600da0fd3fa1bde3ed69e1442aed8a1.jpg not found.
# File dog_breeds/train/d48a8aa150e8ec0f97868af26bcc0a93.jpg not found.
# File dog_breeds/train/b33ebbb55eb1b3ff1587deb055529e00.jpg not found.
# File dog_breeds/train/447a24e3766cde62204d42d571212389.jpg not found.
# File dog_breeds/train/3b3ae8c92f704bf449ea4bc61866461b.jpg not found.
# File dog_breeds/train/1f443edbd2a9e5a77be5d14262b8bd66.jpg not found.
# File dog_breeds/train/08946697b3e50e602d6bea765c8fb9f5.jpg not found.
# File dog_breeds/train/cdb97461991bf6d92b771a0c83076b69.jpg not found.
# File dog_breeds/train/498c124f07f90a5f911a8879a4b53444.jpg not found.
# File dog_breeds/train/eb68d9469a3925897dd1c06bbc5a40d9.jpg not found.
# File dog_breeds/train/ac54633fb411ba5f4a403cb2cef10e9b.jpg not found.
# File dog_breeds/train/7968fee6de08f19f2a783e5b9a8bd46f.jpg not found.
# File dog_breeds/train/d47fcfb7f8b4de12cb78b54eb1c62dcb.jpg not found.
# File dog_breeds/train/85d6ace4a0c1ffdbaf80479b9368ecdf.jpg not found.
# File dog_breeds/train/f184f4ea0aad4cac48670bede5868054.jpg not found.
# File dog_breeds/train/79d2ea336fda1392771cb594f3555945.jpg not found.
# File dog_breeds/train/0b72856996ad5826afff7195ff678589.jpg not found.
# File dog_breeds/train/a234febaeeba77417fd731d9c5d3a692.jpg not found.
# File dog_breeds/train/657c6ab87bd1e49b91d27a571ec12883.jpg not found.
# File dog_breeds/train/452c3d852b0291d7b4c6011348372547.jpg not found.
# File dog_breeds/train/ed650c72271b58dbac0fd5d91ebd206b.jpg not found.

# %%
import os

directory = 'dog_breeds'  # Replace 'dog_breeds' with the path to your directory

# List all files and directories in the specified directory
contents = os.listdir(directory)
print("Contents of the directory:")
print(contents)

# Read the first few lines of each file in the directory
for file_name in contents:
    file_path = os.path.join(directory, file_name)
    if os.path.isfile(file_path):
        print(f"\nFirst few lines of file '{file_name}':")
        with open(file_path, 'r') as file:
            # Read the first 5 lines of each file
            for _ in range(5):
                line = file.readline()
                if line:
                    print(line.strip())  # Print each line without leading/trailing whitespace
                else:
                    break  # If end of file reached, break the loop
# Out:
# Contents of the directory:
# ['labels.csv', 'sample_submission.csv']
#
# First few lines of file 'labels.csv':
# id,breed
# 000bec180eb18c7604dcecc8fe0dba07,boston_bull
# 001513dfcb2ffafc82cccf4d8bbaba97,dingo
# 001cdf01b096e06d78e9e5112d419397,pekinese
# 00214f311d5d2247d5dfe4fe24b2303d,bluetick
#
# First few lines of file 'sample_submission.csv':
# id,affenpinscher,afghan_hound,african_hunting_dog,airedale,american_staffordshire_terrier,appenzeller,australian_terrier,basenji,basset,beagle,bedlington_terrier,bernese_mountain_dog,black-and-tan_coonhound,blenheim_spaniel,bloodhound,bluetick,border_collie,border_terrier,borzoi,boston_bull,bouvier_des_flandres,boxer,brabancon_griffon,briard,brittany_spaniel,bull_mastiff,cairn,cardigan,chesapeake_bay_retriever,chihuahua,chow,clumber,cocker_spaniel,collie,curly-coated_retriever,dandie_dinmont,dhole,dingo,doberman,english_foxhound,english_setter,english_springer,entlebucher,eskimo_dog,flat-coated_retriever,french_bulldog,german_shepherd,german_short-haired_pointer,giant_schnauzer,golden_retriever,gordon_setter,great_dane,great_pyrenees,greater_swiss_mountain_dog,groenendael,ibizan_hound,irish_setter,irish_terrier,irish_water_spaniel,irish_wolfhound,italian_greyhound,japanese_spaniel,keeshond,kelpie,kerry_blue_terrier,komondor,kuvasz,labrador_retriever,lakeland_terrier,leonberg,lhasa,malamute,malinois,maltese_dog,mexican_hairless,miniature_pinscher,miniature_poodle,miniature_schnauzer,newfoundland,norfolk_terrier,norwegian_elkhound,norwich_terrier,old_english_sheepdog,otterhound,papillon,pekinese,pembroke,pomeranian,pug,redbone,rhodesian_ridgeback,rottweiler,saint_bernard,saluki,samoyed,schipperke,scotch_terrier,scottish_deerhound,sealyham_terrier,shetland_sheepdog,shih-tzu,siberian_husky,silky_terrier,soft-coated_wheaten_terrier,staffordshire_bullterrier,standard_poodle,standard_schnauzer,sussex_spaniel,tibetan_mastiff,tibetan_terrier,toy_poodle,toy_terrier,vizsla,walker_hound,weimaraner,welsh_springer_spaniel,west_highland_white_terrier,whippet,wire-haired_fox_terrier,yorkshire_terrier
# 000621fb3cbb32d8935728e48679680e,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333
# 00102ee9d8eb90812350685311fe5890,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333
# 0012a730dfa437f5f3613fb75efcd4ce,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333
# 001510bc8570bbeee98c8d80c8a95ec1,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333,0.00833333333333333

# %% [markdown]
# ## Optional: Build a Baseline CNN
#
# This is an optional step. Adapting a pretrained model will produce better results, but it may be interesting to create a CNN from scratch as a baseline. If you wish to, do so here.

# %%
# Create a baseline CNN model

# %% [markdown]
# ## Loading a Pretrained CNN
#
# ## Feature Engineering with the Pretrained Model
#
# As you may well have guessed, adapting a pretrained model will undoubtedly produce better results then a fresh CNN due to the limited size of training data. Import a pretrained model such as VGG-19 to use a convolutional base. Use this to transform the dataset into a rich feature space and add a few fully connected layers on top of the pretrained layers to build a classification model. (Be sure to leave the pretrained model frozen!)

# %%
# Your code here; add fully connected layers on top of the convolutional base

# %% [markdown]
# ## Visualize History
#
# Now fit the model and visualize the training and validation accuracy/loss functions over successive epochs.

# %%
# Your code here; visualize the training / validation history associated with fitting the model

# %%
# Save model

# %% [markdown]
# ## Final Model Evaluation
#
# Now that you've trained and validated the model, perform a final evaluation of the model on the test set.

# %%
# Your code here

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you brought all of your prior deep learning skills together from preprocessing including one-hot encoding, to adapting a pretrained model. There are always ongoing advancements in CNN architectures and best practices, but you have a solid foundation and understanding at this point.
